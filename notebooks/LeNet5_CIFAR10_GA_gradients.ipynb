# %%
import os
os.chdir('/home/rn7823/fl_lab/centralized_cifar_10')
os.getcwd()
# Out:
# '/home/rn7823/fl_lab/centralized_cifar_10'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_1 = pd.read_csv('LeNet5_2024-09-06-15-22_19197993.csv')
df_1
# Out:
#       Round  train_losses  test_losses  accuracies  gradients
# 0         1      2.297776     0.002302       11.06   0.155381
# 1         2      2.300104     0.002297       17.69   0.134049
# 2         3      2.296942     0.002292       17.71   0.179728
# 3         4      2.292422     0.002285       18.40   0.185786
# 4         5      2.280960     0.002278       18.20   0.248851
# ...     ...           ...          ...         ...        ...
# 3905   3906      2.023902     0.001979       25.25   3.407509
# 3906   3907      2.006418     0.001976       25.62   1.123002
# 3907   3908      2.000822     0.001975       25.76   1.608893
# 3908   3909      2.050297     0.001976       26.02   1.981162
# 3909   3910      2.018747     0.001975       25.91   2.126130
#
# [3910 rows x 5 columns]

# %%
df_sampled_1 = df_1[df_1.index % 100 == 0]

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot for the first y-axis
sns.lineplot(data=df_sampled_1,
             x='Round',
             y='accuracies',
             ax=ax1,                   # Use the first axis
             linewidth=2,             # Line width
             marker='o',              # Marker style
             markersize=6,            # Marker size
             linestyle='-',           # Line style
             alpha=0.8,
             label='Accuracy')        # Add label for legend

# Configure the first y-axis
ax1.set_title('Accuracy and L2 Norm Grad Over Rounds \n (LeNet5 on CIFAR-10 \n q=1000)', fontsize=16)    # Title with font size
ax1.set_xlabel('Round', fontsize=14)                                      # X-axis label with font size
ax1.set_ylabel('Accuracy', fontsize=14)                                   # Y-axis label with font size
ax1.tick_params(axis='both', which='major', labelsize=12)                 # Improve tick appearance
ax1.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)   # Add gridlines

# Add legend for the first y-axis
ax1.legend(loc='upper left', bbox_to_anchor=(0, 1.0), fontsize=12, frameon=True)

# Create a second y-axis
ax2 = ax1.twinx()

# Plot data for the second y-axis
sns.lineplot(data=df_sampled_1,
             x='Round',
             y='gradients',  # Replace with the actual column name for the second y-axis
             ax=ax2,             # Use the second axis
             color='orange',     # Line color for the second y-axis
             linewidth=2,        # Line width
             linestyle='--',     # Line style
             alpha=0.8,
             label='L2 Norm Gradients')  # Add label for legend

# Configure the second y-axis
ax2.set_ylabel('L2 Norm Gradients', fontsize=14)  # Y-axis label for the second axis
ax2.tick_params(axis='y', which='major', labelsize=12)  # Improve tick appearance

# Add legend for the second y-axis (L2 Norm Gradients)
ax2.legend(loc='upper left', bbox_to_anchor=(0, 0.925), fontsize=12, frameon=True)


# Adjust layout to prevent clipping
plt.tight_layout()

# Show the plot
plt.show()

# %%
df_2 = pd.read_csv('LeNet5_2024-09-06-16-48_19198087.csv')
df_2
# Out:
#       Round  train_losses  test_losses  accuracies  gradients
# 0         1      2.308342     0.002304        9.05   0.279083
# 1         2      2.307836     0.002302       10.20   0.245403
# 2         3      2.284317     0.002302       10.43   0.339989
# 3         4      2.279307     0.002302       10.18   0.308923
# 4         5      2.291114     0.002303       10.15   0.216306
# ...     ...           ...          ...         ...        ...
# 7815   7816      2.261195     0.002172       19.68   0.623082
# 7816   7817      2.256057     0.002172       19.71   0.273671
# 7817   7818      2.163890     0.002172       19.70   0.233644
# 7818   7819      2.307778     0.002172       19.71   0.766731
# 7819   7820      2.203660     0.002172       19.69   0.346640
#
# [7820 rows x 5 columns]

# %%
df_sampled_2 = df_2[df_2.index % 100 == 0]
df_2
# Out:
#       Round  train_losses  test_losses  accuracies  gradients
# 0         1      2.308342     0.002304        9.05   0.279083
# 1         2      2.307836     0.002302       10.20   0.245403
# 2         3      2.284317     0.002302       10.43   0.339989
# 3         4      2.279307     0.002302       10.18   0.308923
# 4         5      2.291114     0.002303       10.15   0.216306
# ...     ...           ...          ...         ...        ...
# 7815   7816      2.261195     0.002172       19.68   0.623082
# 7816   7817      2.256057     0.002172       19.71   0.273671
# 7817   7818      2.163890     0.002172       19.70   0.233644
# 7818   7819      2.307778     0.002172       19.71   0.766731
# 7819   7820      2.203660     0.002172       19.69   0.346640
#
# [7820 rows x 5 columns]

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot for the first y-axis
sns.lineplot(data=df_sampled_2,
             x='Round',
             y='accuracies',
             ax=ax1,                   # Use the first axis
             linewidth=2,             # Line width
             marker='o',              # Marker style
             markersize=6,            # Marker size
             linestyle='-',           # Line style
             alpha=0.8,
             label='Accuracy')        # Add label for legend

# Configure the first y-axis
ax1.set_title('Accuracy and L2 Norm Grad Over Rounds \n (LeNet5 on CIFAR-10 \n q=2000)', fontsize=16)    # Title with font size
ax1.set_xlabel('Round', fontsize=14)                                      # X-axis label with font size
ax1.set_ylabel('Accuracy', fontsize=14)                                   # Y-axis label with font size
ax1.tick_params(axis='both', which='major', labelsize=12)                 # Improve tick appearance
ax1.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)   # Add gridlines

# Add legend for the first y-axis
ax1.legend(loc='upper left', bbox_to_anchor=(0, 1.0), fontsize=12, frameon=True)

# Create a second y-axis
ax2 = ax1.twinx()

# Plot data for the second y-axis
sns.lineplot(data=df_sampled_2,
             x='Round',
             y='gradients',  # Replace with the actual column name for the second y-axis
             ax=ax2,             # Use the second axis
             color='orange',     # Line color for the second y-axis
             linewidth=2,        # Line width
             linestyle='--',     # Line style
             alpha=0.8,
             label='L2 Norm Gradients')  # Add label for legend

# Configure the second y-axis
ax2.set_ylabel('L2 Norm Gradients', fontsize=14)  # Y-axis label for the second axis
ax2.tick_params(axis='y', which='major', labelsize=12)  # Improve tick appearance

# Add legend for the second y-axis (L2 Norm Gradients)
ax2.legend(loc='upper left', bbox_to_anchor=(0, 0.925), fontsize=12, frameon=True)


# Adjust layout to prevent clipping
plt.tight_layout()

# Show the plot
plt.show()
